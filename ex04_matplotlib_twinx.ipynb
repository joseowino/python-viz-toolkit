# %% [markdown]
# 4: Matplotlib 2
#
# The goal of this plot is to learn to use Matplotlib to plot different lines in the same plot on different axis using twinx. This very useful to compare variables in different ranges.
#
# Here is the data:
#
# left_data = [5, 7, 11, 13, 17]
# right_data = [0.1, 0.2, 0.4, 0.8, -1.6]
# x_axis = [0.0, 1.0, 2.0, 3.0, 4.0]
# Reproduce this plot
#
# The plot has to contain:
#
# the title
#
# name on left y-axis and right y-axis
#
# style:
#
# left data in black
#
# right data in red

# %%
# Packages

import matplotlib.pyplot as plt

print("Packages Imported Successfully")
# Out:
# Packages Imported Successfully

# %%
# Data

left_data = [5, 7, 11, 13, 17] 
right_data = [0.1, 0.2, 0.4, 0.8, -1.6] 
x_axis = [0.0, 1.0, 2.0, 3.0, 4.0] 

print(f"left_data: {left_data}\nright_data: {right_data}\nx_axis: {x_axis}")
# Out:
# left_data: [5, 7, 11, 13, 17]
# right_data: [0.1, 0.2, 0.4, 0.8, -1.6]
# x_axis: [0.0, 1.0, 2.0, 3.0, 4.0]

# %%
# Chart

fig, ax1 = plt.subplots()
ax1.plot(x_axis, left_data, color='black')
ax1.set_xlabel('x_axis')
ax1.set_ylabel('left_data', color='black')
ax1.tick_params(axis='y', labelcolor='black')

ax2 = ax1.twinx()
ax2.plot(x_axis, right_data, color='red')
ax2.set_ylabel('right_data', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title('Twinx Plot')
# Out:
# Text(0.5, 1.0, 'Twinx Plot')
