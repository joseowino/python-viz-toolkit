# %% [markdown]
# 5: Matplotlib subplots
#
# The goal of this exercise is to learn to use Matplotlib to create subplots.
#
# Reproduce this plot using a for loop:
#
# The plot has to contain:
#
# 6 subplots: 2 rows, 3 columns
#
# Keep space between plots: hspace=0.5 and wspace=0.5
#
# Each plot contains
#
# Text (2,3,i) centered at 0.5, 0.5. Hint: check the parameter ha of text
#
# a title: Title i

# %%
# Packages

import matplotlib.pyplot as plt

print("Packages ImportedSuccessfully...")
# Out:
# Packages ImportedSuccessfully...

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, f'(2, 3, {i})', ha='center')
    ax.set_title(f'Title {i}')

plt.show()
